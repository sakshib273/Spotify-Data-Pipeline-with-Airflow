# %% [markdown]
# ## Extracting Data from S3

# %%
import pandas as pd
import boto3
from io import StringIO
import configparser
from sqlalchemy import create_engine
import psycopg2
from urllib.parse import quote_plus

# %%
config = configparser.ConfigParser()
config.read('/home/sakshi/spotify_project/config.ini')
# Out:
# ['/home/sakshi/spotify_project/config.ini']

# %%
aws_access_key_id = config['aws']['aws_access_key_id']
aws_secret_access_key = config['aws']['aws_secret_access_key']
bucket_name = config['aws']['s3_bucket']
tracks_folder = config['aws']['s3_tracks_folder']
artists_folder = config['aws']['s3_artists_folder']

# %%
s3 = boto3.client(
    's3',
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key
)

# %%
def merge_csvs_from_s3(bucket_name, folder_name):
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=folder_name)
    
    if 'Contents' not in response:
        print(f"No files found in {folder_name}")
        return pd.DataFrame() 
    
    files = response['Contents']
    
    merged_df = pd.DataFrame()
    
    for file in files:
        key = file['Key']
        if key.endswith('.csv'):
            file_obj = s3.get_object(Bucket=bucket_name, Key=key)
            file_content = file_obj['Body'].read().decode('utf-8')
            

            temp_df = pd.read_csv(StringIO(file_content))
            merged_df = pd.concat([merged_df, temp_df], ignore_index=True)
    
    return merged_df

tracks_df = merge_csvs_from_s3(bucket_name, tracks_folder)
artists_df = merge_csvs_from_s3(bucket_name, artists_folder)

# %%
tracks_df.head()
# Out:
#                  track_id                                     track_name  \
# 0  3zSSCPpLZ5Oc8nelhhGjKz                                   Tu hai kahan
# 1  6N4TjPeZi4S9jpayOpRX2h                                Yaarr Ni Milyaa
# 2  3KkXRkHbMCARz0aVfEt68P  Sunflower - Spider-Man: Into the Spider-Verse
# 3  1LNlfvPQmB0cqYJQQskZ8x                       MOMMAE (Feat. Ugly Duck)
# 4  2gkVEnpahpE3bQuvGuCpAV                                      Yes or No
#
#           album_artist_id album_artist_name  duration_ms  explicit  \
# 0  2cjQTf2J5yCaNY8qHpW855               AUR       263184     False
# 1  4ITkqBlf5eoVCOFwsJCnqo     Harrdy Sandhu       310208     False
# 2  246dkjvS1zLTtiykXe5h60       Post Malone       158040     False
# 3  4XDi67ZENZcbfKnvMnTYsI          Jay Park       204991      True
# 4  6HaGTQPmzraVmaVxvz6EUc         Jung Kook       147557     False
#
#    popularity  track_number                played_at  \
# 0          75             1  2024-10-13 10:27:15.217
# 1          61             1  2024-10-13 10:11:59.811
# 2          80             2  2024-10-13 10:06:49.125
# 3          65             4  2024-10-13 09:59:01.287
# 4          76             5  2024-10-12 09:01:38.462
#
#                                            track_url  \
# 0  https://open.spotify.com/track/3zSSCPpLZ5Oc8ne...
# 1  https://open.spotify.com/track/6N4TjPeZi4S9jpa...
# 2  https://open.spotify.com/track/3KkXRkHbMCARz0a...
# 3  https://open.spotify.com/track/1LNlfvPQmB0cqYJ...
# 4  https://open.spotify.com/track/2gkVEnpahpE3bQu...
#
#                                           artist_url                album_id  \
# 0  https://open.spotify.com/artist/2cjQTf2J5yCaNY...  73vfz6Szer7i3GFIesix6l
# 1  https://open.spotify.com/artist/4ITkqBlf5eoVCO...  40YiNI76fpTK5IXRv4VbHP
# 2  https://open.spotify.com/artist/246dkjvS1zLTti...  35s58BRTGAEWztPo9WqCIs
# 3  https://open.spotify.com/artist/4XDi67ZENZcbfK...  5vESroqrGYDxDPAwUceQxf
# 4  https://open.spotify.com/artist/6HaGTQPmzraVma...  5pSk3c3wVwnb2arb6ohCPU
#
#                                           album_name album_release_date  \
# 0                                       Tu hai kahan         2023-10-16
# 1                                    Yaarr Ni Milyaa         2017-09-05
# 2  Spider-Man: Into the Spider-Verse (Soundtrack ...         2018-12-14
# 3                                          WORLDWIDE         2015-11-05
# 4                                             GOLDEN         2023-11-03
#
#    total_tracks                                          album_url  \
# 0             1  https://open.spotify.com/album/73vfz6Szer7i3GF...
# 1             1  https://open.spotify.com/album/40YiNI76fpTK5IX...
# 2            13  https://open.spotify.com/album/35s58BRTGAEWztP...
# 3            18  https://open.spotify.com/album/5vESroqrGYDxDPA...
# 4            11  https://open.spotify.com/album/5pSk3c3wVwnb2ar...
#
#   context_type                                       playlist_url
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4     playlist  https://open.spotify.com/playlist/37i9dQZF1EQp...

# %%
tracks_df.count()
# Out:
# track_id              2651
# track_name            2651
# album_artist_id       2651
# album_artist_name     2651
# duration_ms           2651
# explicit              2651
# popularity            2651
# track_number          2651
# played_at             2651
# track_url             2651
# artist_url            2651
# album_id              2651
# album_name            2651
# album_release_date    2651
# total_tracks          2651
# album_url             2651
# context_type           102
# playlist_url           102
# dtype: int64

# %%
artists_df.head()
# Out:
#                  track_id               artist_id   artist_name
# 0  2plbrEY59IikOBgBGLjaoe  1HY2Jd0NmPuamShAr6KMms     Lady Gaga
# 1  2plbrEY59IikOBgBGLjaoe  0du5cEVh5yTK9QJze8zA0C    Bruno Mars
# 2  2CspwnypzT7rcWI9RfsoSb  250b0Wlc5Vk0CoUsaCY84M        JENNIE
# 3  5jsw9uXEGuKyJzs0boZ1bT  7n2wHs1TKAczGzO7Dd2rGr  Shawn Mendes
# 4  01prGWjCTxKBxJc400zwvQ  5L1lO4eRHmJ7a0Q6csE5cT          LISA

# %%
artists_df.count()
# Out:
# track_id       4392
# artist_id      4392
# artist_name    4392
# dtype: int64

# %% [markdown]
# ## Transformation

# %%
new_tracks = tracks_df.drop_duplicates()

# %%
new_tracks.count()
# Out:
# track_id              1113
# track_name            1113
# album_artist_id       1113
# album_artist_name     1113
# duration_ms           1113
# explicit              1113
# popularity            1113
# track_number          1113
# played_at             1113
# track_url             1113
# artist_url            1113
# album_id              1113
# album_name            1113
# album_release_date    1113
# total_tracks          1113
# album_url             1113
# context_type            66
# playlist_url            66
# dtype: int64

# %%
new_artists = artists_df.drop_duplicates()

# %%
new_artists.count()
# Out:
# track_id       1200
# artist_id      1200
# artist_name    1200
# dtype: int64

# %%
new_tracks.dtypes
# Out:
# track_id              object
# track_name            object
# album_artist_id       object
# album_artist_name     object
# duration_ms            int64
# explicit                bool
# popularity             int64
# track_number           int64
# played_at             object
# track_url             object
# artist_url            object
# album_id              object
# album_name            object
# album_release_date    object
# total_tracks           int64
# album_url             object
# context_type          object
# playlist_url          object
# dtype: object

# %%
new_tracks = new_tracks.copy()
new_tracks['played_at_date'] = new_tracks['played_at']

# %%
new_tracks[['track_name','played_at_date']]
# Out:
#                                          track_name  \
# 0                                      Tu hai kahan
# 1                                   Yaarr Ni Milyaa
# 2     Sunflower - Spider-Man: Into the Spider-Verse
# 3                          MOMMAE (Feat. Ugly Duck)
# 4                                         Yes or No
# ...                                             ...
# 2596                  Fighting (Feat. Lee Young Ji)
# 2597                               Fat Funny Friend
# 2598                       Happier Than Ever - Edit
# 2599                           Sparkle - movie ver.
# 2600                                        History
#
#                         played_at_date
# 0              2024-10-13 10:27:15.217
# 1              2024-10-13 10:11:59.811
# 2              2024-10-13 10:06:49.125
# 3              2024-10-13 09:59:01.287
# 4              2024-10-12 09:01:38.462
# ...                                ...
# 2596  2024-11-30 12:53:52.566000+05:30
# 2597  2024-11-30 12:50:27.566000+05:30
# 2598  2024-11-30 12:47:07.073000+05:30
# 2599  2024-11-30 12:43:43.540000+05:30
# 2600  2024-11-30 12:34:45.394000+05:30
#
# [1113 rows x 2 columns]

# %%
new_tracks['played_at_date'] = new_tracks['played_at_date'].str.split(' ').str[0]

# %%
new_tracks['played_at_date'] = pd.to_datetime(new_tracks['played_at_date'])

# %%
new_tracks['played_at'] = new_tracks['played_at'].str.replace(r'\+.*', '', regex=True)

# %%
new_tracks['played_at'] = new_tracks['played_at'].str.split('.').str[0]

# %%
new_tracks['played_at'] = pd.to_datetime(new_tracks['played_at']).dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
new_tracks
# Out:
#                     track_id                                     track_name  \
# 0     3zSSCPpLZ5Oc8nelhhGjKz                                   Tu hai kahan
# 1     6N4TjPeZi4S9jpayOpRX2h                                Yaarr Ni Milyaa
# 2     3KkXRkHbMCARz0aVfEt68P  Sunflower - Spider-Man: Into the Spider-Verse
# 3     1LNlfvPQmB0cqYJQQskZ8x                       MOMMAE (Feat. Ugly Duck)
# 4     2gkVEnpahpE3bQuvGuCpAV                                      Yes or No
# ...                      ...                                            ...
# 2596  7eBpUuPnDTfbeP1P4P93CS                  Fighting (Feat. Lee Young Ji)
# 2597  7z3NjKBqjv3d1ykXCFQxaT                               Fat Funny Friend
# 2598  32BeYxKPrig1LefHsC0Xuo                       Happier Than Ever - Edit
# 2599  3A4FRzgve9BjfKbvVXRIFO                           Sparkle - movie ver.
# 2600  0HMjXBAZmSYOTTi33WpMso                                        History
#
#              album_artist_id album_artist_name  duration_ms  explicit  \
# 0     2cjQTf2J5yCaNY8qHpW855               AUR       263184     False
# 1     4ITkqBlf5eoVCOFwsJCnqo     Harrdy Sandhu       310208     False
# 2     246dkjvS1zLTtiykXe5h60       Post Malone       158040     False
# 3     4XDi67ZENZcbfKnvMnTYsI          Jay Park       204991      True
# 4     6HaGTQPmzraVmaVxvz6EUc         Jung Kook       147557     False
# ...                      ...               ...          ...       ...
# 2596  1uAT5bTSp6dWbNmixIUP5t               BSS       204466     False
# 2597  5dtPlx7yKOo7KdZGyrfFIq       Maddie Zahm       199764     False
# 2598  6qqNVTkY8uBg9cP3Jd7DAH     Billie Eilish       151444      True
# 2599  1EowJ1WwkMzkCkRomFhui7          RADWIMPS       537653     False
# 2600  4AK6F7OLvEQ5QYCBNiQWHq     One Direction       187426     False
#
#       popularity  track_number            played_at  \
# 0             75             1  2024-10-13 10:27:15
# 1             61             1  2024-10-13 10:11:59
# 2             80             2  2024-10-13 10:06:49
# 3             65             4  2024-10-13 09:59:01
# 4             76             5  2024-10-12 09:01:38
# ...          ...           ...                  ...
# 2596          67             1  2024-11-30 12:53:52
# 2597          64             1  2024-11-30 12:50:27
# 2598          69             1  2024-11-30 12:47:07
# 2599          64            24  2024-11-30 12:43:43
# 2600          75            13  2024-11-30 12:34:45
#
#                                               track_url  \
# 0     https://open.spotify.com/track/3zSSCPpLZ5Oc8ne...
# 1     https://open.spotify.com/track/6N4TjPeZi4S9jpa...
# 2     https://open.spotify.com/track/3KkXRkHbMCARz0a...
# 3     https://open.spotify.com/track/1LNlfvPQmB0cqYJ...
# 4     https://open.spotify.com/track/2gkVEnpahpE3bQu...
# ...                                                 ...
# 2596  https://open.spotify.com/track/7eBpUuPnDTfbeP1...
# 2597  https://open.spotify.com/track/7z3NjKBqjv3d1yk...
# 2598  https://open.spotify.com/track/32BeYxKPrig1Lef...
# 2599  https://open.spotify.com/track/3A4FRzgve9BjfKb...
# 2600  https://open.spotify.com/track/0HMjXBAZmSYOTTi...
#
#                                              artist_url  \
# 0     https://open.spotify.com/artist/2cjQTf2J5yCaNY...
# 1     https://open.spotify.com/artist/4ITkqBlf5eoVCO...
# 2     https://open.spotify.com/artist/246dkjvS1zLTti...
# 3     https://open.spotify.com/artist/4XDi67ZENZcbfK...
# 4     https://open.spotify.com/artist/6HaGTQPmzraVma...
# ...                                                 ...
# 2596  https://open.spotify.com/artist/1uAT5bTSp6dWbN...
# 2597  https://open.spotify.com/artist/5dtPlx7yKOo7Kd...
# 2598  https://open.spotify.com/artist/6qqNVTkY8uBg9c...
# 2599  https://open.spotify.com/artist/1EowJ1WwkMzkCk...
# 2600  https://open.spotify.com/artist/4AK6F7OLvEQ5QY...
#
#                     album_id  \
# 0     73vfz6Szer7i3GFIesix6l
# 1     40YiNI76fpTK5IXRv4VbHP
# 2     35s58BRTGAEWztPo9WqCIs
# 3     5vESroqrGYDxDPAwUceQxf
# 4     5pSk3c3wVwnb2arb6ohCPU
# ...                      ...
# 2596  4dHtpne5cAAGgDYFNHu7jW
# 2597  5NMKRqxbne8L5LerDnpGjk
# 2598  2kzPJWrTjVKEYWWhowXLnz
# 2599  4qApTp9557qYZzRLEih4uP
# 2600  1gMxiQQSg5zeu4htBosASY
#
#                                              album_name album_release_date  \
# 0                                          Tu hai kahan         2023-10-16
# 1                                       Yaarr Ni Milyaa         2017-09-05
# 2     Spider-Man: Into the Spider-Verse (Soundtrack ...         2018-12-14
# 3                                             WORLDWIDE         2015-11-05
# 4                                                GOLDEN         2023-11-03
# ...                                                 ...                ...
# 2596                 BSS 1st Single Album 'SECOND WIND'         2023-02-06
# 2597                                   Fat Funny Friend         2022-02-04
# 2598                           Happier Than Ever (Edit)         2021-07-28
# 2599                                         Your Name.         2016-08-24
# 2600                  Made In The A.M. (Deluxe Edition)         2015-11-13
#
#       total_tracks                                          album_url  \
# 0                1  https://open.spotify.com/album/73vfz6Szer7i3GF...
# 1                1  https://open.spotify.com/album/40YiNI76fpTK5IX...
# 2               13  https://open.spotify.com/album/35s58BRTGAEWztP...
# 3               18  https://open.spotify.com/album/5vESroqrGYDxDPA...
# 4               11  https://open.spotify.com/album/5pSk3c3wVwnb2ar...
# ...            ...                                                ...
# 2596             3  https://open.spotify.com/album/4dHtpne5cAAGgDY...
# 2597             1  https://open.spotify.com/album/5NMKRqxbne8L5Le...
# 2598             1  https://open.spotify.com/album/2kzPJWrTjVKEYWW...
# 2599            27  https://open.spotify.com/album/4qApTp9557qYZzR...
# 2600            17  https://open.spotify.com/album/1gMxiQQSg5zeu4h...
#
#      context_type                                       playlist_url  \
# 0             NaN                                                NaN
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4        playlist  https://open.spotify.com/playlist/37i9dQZF1EQp...
# ...           ...                                                ...
# 2596          NaN                                                NaN
# 2597          NaN                                                NaN
# 2598          NaN                                                NaN
# 2599          NaN                                                NaN
# 2600          NaN                                                NaN
#
#      played_at_date
# 0        2024-10-13
# 1        2024-10-13
# 2        2024-10-13
# 3        2024-10-13
# 4        2024-10-12
# ...             ...
# 2596     2024-11-30
# 2597     2024-11-30
# 2598     2024-11-30
# 2599     2024-11-30
# 2600     2024-11-30
#
# [1113 rows x 19 columns]

# %%
new_tracks[['track_name','explicit']].where(new_tracks['explicit'] == True).count()
# Out:
# track_name    88
# explicit      88
# dtype: int64

# %%
new_artists.dtypes
# Out:
# track_id       object
# artist_id      object
# artist_name    object
# dtype: object

# %% [markdown]
# ## Dimension Modelling

# %%
new_tracks.head()
# Out:
#                  track_id                                     track_name  \
# 0  3zSSCPpLZ5Oc8nelhhGjKz                                   Tu hai kahan
# 1  6N4TjPeZi4S9jpayOpRX2h                                Yaarr Ni Milyaa
# 2  3KkXRkHbMCARz0aVfEt68P  Sunflower - Spider-Man: Into the Spider-Verse
# 3  1LNlfvPQmB0cqYJQQskZ8x                       MOMMAE (Feat. Ugly Duck)
# 4  2gkVEnpahpE3bQuvGuCpAV                                      Yes or No
#
#           album_artist_id album_artist_name  duration_ms  explicit  \
# 0  2cjQTf2J5yCaNY8qHpW855               AUR       263184     False
# 1  4ITkqBlf5eoVCOFwsJCnqo     Harrdy Sandhu       310208     False
# 2  246dkjvS1zLTtiykXe5h60       Post Malone       158040     False
# 3  4XDi67ZENZcbfKnvMnTYsI          Jay Park       204991      True
# 4  6HaGTQPmzraVmaVxvz6EUc         Jung Kook       147557     False
#
#    popularity  track_number            played_at  \
# 0          75             1  2024-10-13 10:27:15
# 1          61             1  2024-10-13 10:11:59
# 2          80             2  2024-10-13 10:06:49
# 3          65             4  2024-10-13 09:59:01
# 4          76             5  2024-10-12 09:01:38
#
#                                            track_url  \
# 0  https://open.spotify.com/track/3zSSCPpLZ5Oc8ne...
# 1  https://open.spotify.com/track/6N4TjPeZi4S9jpa...
# 2  https://open.spotify.com/track/3KkXRkHbMCARz0a...
# 3  https://open.spotify.com/track/1LNlfvPQmB0cqYJ...
# 4  https://open.spotify.com/track/2gkVEnpahpE3bQu...
#
#                                           artist_url                album_id  \
# 0  https://open.spotify.com/artist/2cjQTf2J5yCaNY...  73vfz6Szer7i3GFIesix6l
# 1  https://open.spotify.com/artist/4ITkqBlf5eoVCO...  40YiNI76fpTK5IXRv4VbHP
# 2  https://open.spotify.com/artist/246dkjvS1zLTti...  35s58BRTGAEWztPo9WqCIs
# 3  https://open.spotify.com/artist/4XDi67ZENZcbfK...  5vESroqrGYDxDPAwUceQxf
# 4  https://open.spotify.com/artist/6HaGTQPmzraVma...  5pSk3c3wVwnb2arb6ohCPU
#
#                                           album_name album_release_date  \
# 0                                       Tu hai kahan         2023-10-16
# 1                                    Yaarr Ni Milyaa         2017-09-05
# 2  Spider-Man: Into the Spider-Verse (Soundtrack ...         2018-12-14
# 3                                          WORLDWIDE         2015-11-05
# 4                                             GOLDEN         2023-11-03
#
#    total_tracks                                          album_url  \
# 0             1  https://open.spotify.com/album/73vfz6Szer7i3GF...
# 1             1  https://open.spotify.com/album/40YiNI76fpTK5IX...
# 2            13  https://open.spotify.com/album/35s58BRTGAEWztP...
# 3            18  https://open.spotify.com/album/5vESroqrGYDxDPA...
# 4            11  https://open.spotify.com/album/5pSk3c3wVwnb2ar...
#
#   context_type                                       playlist_url  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4     playlist  https://open.spotify.com/playlist/37i9dQZF1EQp...
#
#   played_at_date
# 0     2024-10-13
# 1     2024-10-13
# 2     2024-10-13
# 3     2024-10-13
# 4     2024-10-12

# %%
new_artists.head()
# Out:
#                  track_id               artist_id   artist_name
# 0  2plbrEY59IikOBgBGLjaoe  1HY2Jd0NmPuamShAr6KMms     Lady Gaga
# 1  2plbrEY59IikOBgBGLjaoe  0du5cEVh5yTK9QJze8zA0C    Bruno Mars
# 2  2CspwnypzT7rcWI9RfsoSb  250b0Wlc5Vk0CoUsaCY84M        JENNIE
# 3  5jsw9uXEGuKyJzs0boZ1bT  7n2wHs1TKAczGzO7Dd2rGr  Shawn Mendes
# 4  01prGWjCTxKBxJc400zwvQ  5L1lO4eRHmJ7a0Q6csE5cT          LISA

# %% [markdown]
# ## Jupyter to Postgres

# %%
config = configparser.ConfigParser()
config.read('config.ini')

# %%
dbname = config['database']['dbname']
user = config['database']['user']
password = config['database']['password']
port = int(config['database']['port'])
host = config['database']['host']

# %%
try:
    conn = psycopg2.connect(dbname=dbname, user=user, password=password, host=host, port=port)
    print("Database connection successful with psycopg2")
except psycopg2.Error as e:
    print(f"Database connection error with psycopg2: {e}")

# %%
cur = conn.cursor()

# %%
quoted_password = quote_plus(password)

# %%
engine = create_engine(f'postgresql+psycopg2://{user}:{quoted_password}@{host}:{port}/{dbname}')

# %%
try:
    cur.execute("""
    DROP TABLE IF EXISTS tracks;
    CREATE TABLE tracks(
    track_id varchar,
    track_name varchar,
    album_artist_id varchar,
    album_artist_name varchar,
    duration_ms int,
    explicit bool,
    popularity int,
    track_number int,
    played_at timestamp,
    track_url text,
    artist_url text,
    album_id varchar,
    album_name varchar,
    album_release_date date,
    total_tracks int,
    album_url varchar,
    context_type varchar,
    playlist_url text,
    played_at_date date
    );
    """)
    conn.commit()
    print('Table Created Successfully')
except psycopg2.Error as e:
    print(e)
    conn.rollback()
# Out:
# Table Created Successfully

# %%
new_tracks.to_sql('tracks',con=engine,if_exists='replace',index=False)
# Out:
# 113

# %%
try:
    cur.execute("""
    DROP TABLE IF EXISTS artists;
    CREATE TABLE artists(
    track_id varchar,
    artist_id varchar,
    artist_name varchar
    );
    """)
    conn.commit()
    print('Table Created Successfully')
except psycopg2.Error as e:
    print(e)
finally:
    cur.close()
    conn.close()
# Out:
# Table Created Successfully

# %%
new_artists.to_sql('artists',con=engine,if_exists='replace',index=False)
# Out:
# 200
